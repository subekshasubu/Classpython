# %%
#wap fr billing for a shop
#wap for result management system
#wap for

# %%
    

# WAP for billing (accounting) for a shop
# Customer Details
customerName = ''
customerContactNo = ''
customerAddress = ''
productName = ''
productQuantity = 0
totalPrice = 0
def custInput():
    customerName = input("\nEnter customer name: ")
    customerContactNo = input("Enter customer contact number: ")
    customerAddress = input("Enter customer Address: ")
    #
    ans = 'y'
    while ans == 'y' or ans == 'Y':
            productName = input("Enter product name to add in order: ")
            productQuantity = int(input("Enter product quantity: "))
            totalPrice = 0
    for product in products:
                if productName.lower() == product.get('Name').lower():
                    totalPrice = productQuantity * product.get('Rate')
                    productOrders.append({​​​​​​​​'Name': product.get('Name'), 'Rate': product.get('Rate'),
                                          'Quantity': productQuantity,
                                          'TotalPrice': totalPrice}​​​​​​​​)
                ans = input("Do you want to continue")
                print("\n**** Billing ****\n")
    # DISPLAY
def Display():
    grandTotal = 0
    print("Customer Name: ", customerName)
    print("Contact Number: ", customerContactNo)
    print("Customer Address: ", customerAddress)
    print("\nProduct name\t | Rate\t | Quantity\t | TotalPrice")
    for product in productOrders:
        grandTotal = grandTotal + product.get("TotalPrice")
        print(
                f'{​​​​​​​​product.get("Name")}​​​​​​​​\t | {​​​​​​​​product.get("Rate")}​​​​​​​​\t | {​​​​​​​​product.get("Quantity")}​​​​​​​​\t\t | {​​​​​​​​product.get("TotalPrice")}​​​​​​​​')
        print(f'\nGrand Total: {​​​​​​​​grandTotal}​​​​​​​​\n')

    # Delete
def Delete():
        itemDelete = input("Enter which product you want to remove from order: ")
        for i in range(len(productOrders)):
                # print(productOrders[i])
            if itemDelete.lower() == productOrders[i].get('Name').lower():
                del productOrders[i]
                print("\n**** Billing Details after Delete ****\n ")
            Display()

    # Update
def Update():
    itemUpdate = input("Enter the product you want to update the details:")
        # print(productOrders)
    updatedTotalPrice = 0
    for i in range(len(productOrders)):
        if itemUpdate.lower() == productOrders[i].get('Name').lower():
            newQuantity = int(input("Enter new quantity: "))
            productOrders[i]['Quantity'] = newQuantity
            productOrders[i]['TotalPrice'] = productOrders[i]['Quantity'] * productOrders[i]['Rate']
        print("\n**** Billing Details after Update ****\n ")
        Display()

print("\n++++++ Welcome to ABC Company Billing Management System ++++++\n")
    # Display Items in Stores
productOrders = []
products = [{​​​​​​​​
        'Name': 'WiWi Noodle',
        'Rate': 20,
        'Quantity': 150
    }​​​​​​​​,
        {​​​​​​​​
            'Name': 'Marie Gold',
            'Rate': 30,
            'Quantity': 100
    }​​​​​​​​,
        {​​​​​​​​
            'Name': 'Dove Shampoo',
            'Rate': 200,
            'Quantity': 100
    }​​​​​​​​,
        {​​​​​​​​
            'Name': 'Garnier Face Wash',
            'Rate': 350,
            'Quantity': 10
    }​​​​​​​​
    ]
print("\n****** List of Items present in Store ******")
print("\nProduct name\t | Rate\t | Quantity")
for items in range(len(products)):
    print(f"{​​​​​​​​products[items]['Name']}​​​​​​​​\t\t | {​​​​​​​​products[items]['Rate']}​​​​​​​​\t\t | {​​​​​​​​products[items]['Quantity']}​​​​​​​​")
custInput()
Display()
Delete()
Update()
# Out:
#   File "<ipython-input-14-9c306b19c76d>", line 22
#     productOrders.append({​​​​​​​​'Name': product.get('Name'), 'Rate': product.get('Rate'),
#                                  ^
# SyntaxError: invalid character in identifier
